# %% [markdown]
# <a href="https://colab.research.google.com/github/NahimaY/probabilidadyestadistica/blob/main/Unidad%201/Practica_4_y_5_Santillan_Marquez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# # Unidad 1
#
# **Practica 4.**Tablas de Frecuencia
#
# **Facilitador:** Dr.José Gabriel Rodriguez Rivas
#
# **Alumno:** Nahima Yoshigei Santillán Márquez.

# %%
import random
edades = []
for i in range(100):
  numero_aleatorio = random.randint( 18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [36, 59, 67, 57, 21, 63, 59, 42, 36, 22, 64, 44, 30, 27, 63, 28, 66, 52, 51, 40, 69, 29, 57, 48, 40, 51, 39, 54, 55, 70, 23, 58, 53, 46, 46, 65, 41, 40, 26, 59, 40, 54, 66, 69, 64, 40, 34, 51, 64, 26, 43, 51, 41, 20, 30, 70, 61, 20, 66, 51, 66, 63, 49, 19, 60, 48, 48, 37, 27, 60, 24, 25, 61, 22, 26, 56, 59, 20, 32, 34, 36, 60, 56, 56, 20, 64, 35, 41, 55, 30, 51, 53, 63, 29, 40, 35, 42, 52, 27, 60]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
#Se creo un DataFrame de pandas con los numeros aleatorios:)
# Out:
#    Edad
# 0    36
# 1    59
# 2    67
# 3    57
# 4    21

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

print("Tabla de Distribucion de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribucion de Frecuencias:
#     Edad  Frecuencia
# 36    19           1
# 5     20           4
# 34    21           1
# 26    22           2
# 37    23           1
# 39    24           1
# 40    25           1
# 12    26           3
# 8     27           3
# 30    28           1
# 25    29           2
# 14    30           3
# 42    32           1
# 17    34           2
# 27    35           2
# 11    36           3
# 38    37           1
# 43    39           1
# 0     40           6
# 10    41           3
# 22    42           2
# 32    43           1
# 31    44           1
# 16    46           2
# 9     48           3
# 35    49           1
# 1     51           6
# 23    52           2
# 19    53           2
# 15    54           2
# 21    55           2
# 13    56           3
# 24    57           2
# 33    58           1
# 2     59           4
# 3     60           4
# 18    61           2
# 4     63           4
# 6     64           4
# 29    65           1
# 7     66           4
# 41    67           1
# 28    69           2
# 20    70           2

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 36    19           1           0.01
# 5     20           4           0.04
# 34    21           1           0.01
# 26    22           2           0.02
# 37    23           1           0.01
# 39    24           1           0.01
# 40    25           1           0.01
# 12    26           3           0.03
# 8     27           3           0.03
# 30    28           1           0.01
# 25    29           2           0.02
# 14    30           3           0.03
# 42    32           1           0.01
# 17    34           2           0.02
# 27    35           2           0.02
# 11    36           3           0.03
# 38    37           1           0.01
# 43    39           1           0.01
# 0     40           6           0.06
# 10    41           3           0.03
# 22    42           2           0.02
# 32    43           1           0.01
# 31    44           1           0.01
# 16    46           2           0.02
# 9     48           3           0.03
# 35    49           1           0.01
# 1     51           6           0.06
# 23    52           2           0.02
# 19    53           2           0.02
# 15    54           2           0.02
# 21    55           2           0.02
# 13    56           3           0.03
# 24    57           2           0.02
# 33    58           1           0.01
# 2     59           4           0.04
# 3     60           4           0.04
# 18    61           2           0.02
# 4     63           4           0.04
# 6     64           4           0.04
# 29    65           1           0.01
# 7     66           4           0.04
# 41    67           1           0.01
# 28    69           2           0.02
# 20    70           2           0.02

# %%
tabla_frecuencias['Frec porcentual'] = tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec porcentual
# 36    19           1           0.01              1.0
# 5     20           4           0.04              4.0
# 34    21           1           0.01              1.0
# 26    22           2           0.02              2.0
# 37    23           1           0.01              1.0
# 39    24           1           0.01              1.0
# 40    25           1           0.01              1.0
# 12    26           3           0.03              3.0
# 8     27           3           0.03              3.0
# 30    28           1           0.01              1.0
# 25    29           2           0.02              2.0
# 14    30           3           0.03              3.0
# 42    32           1           0.01              1.0
# 17    34           2           0.02              2.0
# 27    35           2           0.02              2.0
# 11    36           3           0.03              3.0
# 38    37           1           0.01              1.0
# 43    39           1           0.01              1.0
# 0     40           6           0.06              6.0
# 10    41           3           0.03              3.0
# 22    42           2           0.02              2.0
# 32    43           1           0.01              1.0
# 31    44           1           0.01              1.0
# 16    46           2           0.02              2.0
# 9     48           3           0.03              3.0
# 35    49           1           0.01              1.0
# 1     51           6           0.06              6.0
# 23    52           2           0.02              2.0
# 19    53           2           0.02              2.0
# 15    54           2           0.02              2.0
# 21    55           2           0.02              2.0
# 13    56           3           0.03              3.0
# 24    57           2           0.02              2.0
# 33    58           1           0.01              1.0
# 2     59           4           0.04              4.0
# 3     60           4           0.04              4.0
# 18    61           2           0.02              2.0
# 4     63           4           0.04              4.0
# 6     64           4           0.04              4.0
# 29    65           1           0.01              1.0
# 7     66           4           0.04              4.0
# 41    67           1           0.01              1.0
# 28    69           2           0.02              2.0
# 20    70           2           0.02              2.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec porcentual  Frec Acumulada
# 36    19           1           0.01              1.0               1
# 5     20           4           0.04              4.0               5
# 34    21           1           0.01              1.0               6
# 26    22           2           0.02              2.0               8
# 37    23           1           0.01              1.0               9
# 39    24           1           0.01              1.0              10
# 40    25           1           0.01              1.0              11
# 12    26           3           0.03              3.0              14
# 8     27           3           0.03              3.0              17
# 30    28           1           0.01              1.0              18
# 25    29           2           0.02              2.0              20
# 14    30           3           0.03              3.0              23
# 42    32           1           0.01              1.0              24
# 17    34           2           0.02              2.0              26
# 27    35           2           0.02              2.0              28
# 11    36           3           0.03              3.0              31
# 38    37           1           0.01              1.0              32
# 43    39           1           0.01              1.0              33
# 0     40           6           0.06              6.0              39
# 10    41           3           0.03              3.0              42
# 22    42           2           0.02              2.0              44
# 32    43           1           0.01              1.0              45
# 31    44           1           0.01              1.0              46
# 16    46           2           0.02              2.0              48
# 9     48           3           0.03              3.0              51
# 35    49           1           0.01              1.0              52
# 1     51           6           0.06              6.0              58
# 23    52           2           0.02              2.0              60
# 19    53           2           0.02              2.0              62
# 15    54           2           0.02              2.0              64
# 21    55           2           0.02              2.0              66
# 13    56           3           0.03              3.0              69
# 24    57           2           0.02              2.0              71
# 33    58           1           0.01              1.0              72
# 2     59           4           0.04              4.0              76
# 3     60           4           0.04              4.0              80
# 18    61           2           0.02              2.0              82
# 4     63           4           0.04              4.0              86
# 6     64           4           0.04              4.0              90
# 29    65           1           0.01              1.0              91
# 7     66           4           0.04              4.0              95
# 41    67           1           0.01              1.0              96
# 28    69           2           0.02              2.0              98
# 20    70           2           0.02              2.0             100

# %% [markdown]
# # Regla de sturges

# %%
import math

# %%
print(edades)
# Out:
# [36, 59, 67, 57, 21, 63, 59, 42, 36, 22, 64, 44, 30, 27, 63, 28, 66, 52, 51, 40, 69, 29, 57, 48, 40, 51, 39, 54, 55, 70, 23, 58, 53, 46, 46, 65, 41, 40, 26, 59, 40, 54, 66, 69, 64, 40, 34, 51, 64, 26, 43, 51, 41, 20, 30, 70, 61, 20, 66, 51, 66, 63, 49, 19, 60, 48, 48, 37, 27, 60, 24, 25, 61, 22, 26, 56, 59, 20, 32, 34, 36, 60, 56, 56, 20, 64, 35, 41, 55, 30, 51, 53, 63, 29, 40, 35, 42, 52, 27, 60]

# %%
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     36
# 1     59
# 2     67
# 3     57
# 4     21
# ..   ...
# 95    35
# 96    42
# 97    52
# 98    27
# 99    60
#
# [100 rows x 1 columns]

# %%
n = len(edades)

k = int( 1 + math.log2(n))
print("Valor de n = ", n ," \nNumero de intervalos =", k)
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
tabla_frecuencia = pd.cut( df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase','Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0    (62.714, 70.0]    18
# 1  (55.429, 62.714]    16
# 2  (33.571, 40.857]    15
# 3  (48.143, 55.429]    15
# 4  (18.948, 26.286]    14
# 5  (40.857, 48.143]    12
# 6  (26.286, 33.571]    10

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 4  (18.948, 26.286]    14
# 6  (26.286, 33.571]    10
# 2  (33.571, 40.857]    15
# 5  (40.857, 48.143]    12
# 3  (48.143, 55.429]    15
# 1  (55.429, 62.714]    16
# 0    (62.714, 70.0]    18

# %%
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec']  / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 4  (18.948, 26.286]    14      0.14       14.0       14         0.14
# 6  (26.286, 33.571]    10      0.10       10.0       24         0.24
# 2  (33.571, 40.857]    15      0.15       15.0       39         0.39
# 5  (40.857, 48.143]    12      0.12       12.0       51         0.51
# 3  (48.143, 55.429]    15      0.15       15.0       66         0.66
# 1  (55.429, 62.714]    16      0.16       16.0       82         0.82
# 0    (62.714, 70.0]    18      0.18       18.0      100         1.00
#
#    Frec Porc Ac
# 4          14.0
# 6          24.0
# 2          39.0
# 5          51.0
# 3          66.0
# 1          82.0
# 0         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5 , bins = 20)
plt.title("Histograma de edades basado en la gfuncion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la gfuncion de matplotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins=k, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# # Unidad 1.
# **Practica 5.** Diagramas de Cajas y bigotes
#
# **Facilitador:** Dr. José Gabriel Rodriguez Rivas
#
# **Alumno:** Nahima Yoshigei Santillán Márquez

# %%
import random
edades2 = []
for i in range(100):
  numero_aleatorio = random.randint( 20, 87)
  edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [81, 48, 38, 45, 84, 79, 78, 70, 62, 38, 31, 62, 75, 30, 42, 77, 74, 33, 67, 23, 22, 46, 60, 41, 60, 63, 80, 63, 26, 64, 36, 54, 87, 42, 58, 87, 38, 64, 66, 74, 65, 57, 57, 47, 59, 45, 42, 73, 59, 79, 75, 48, 32, 74, 50, 73, 28, 43, 30, 44, 31, 54, 75, 38, 29, 63, 30, 79, 74, 22, 29, 63, 57, 26, 50, 85, 82, 63, 32, 49, 83, 26, 79, 20, 87, 54, 59, 49, 84, 69, 79, 66, 67, 23, 84, 28, 76, 45, 21, 53]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades,
                     vert=True,
                     patch_artist=True)
ax1.set_title('Edades Encuenta 1')

bplot2 = ax2.boxplot(edades2,
                     vert=True,
                     patch_artist=True)
ax2.set_title('Edades Encuenta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades,
                     vert=True,
                     patch_artist=True)
ax1.set_title('Edades Encuenta 1')

bplot2 = ax2.boxplot(edades2,
                     vert=True,
                     patch_artist=True)
ax2.set_title('Edades Encuenta 2')
plt.show()
